# %%
from DRepGenVLM.configs.DRGVLM_baseConfig import DRGVLM_baseConfig

DRGVLM_baseConfig.setup_configs(
    save_path='/home/yasaisen/Desktop/27_research/research_main_v3/lab_18/DRepGenVLM/DRepGenVLM/projects',
)
# Out:
# [15:47:09] [DRGVLM_baseConfig.save] Saved config to /home/yasaisen/Desktop/27_research/research_main_v3/lab_18/DRepGenVLM/DRepGenVLM/projects/MG15_basic_overfitTesting_config_hpc.json
# [15:47:09] [DRGVLM_baseConfig.save] Saved config to /home/yasaisen/Desktop/27_research/research_main_v3/lab_18/DRepGenVLM/DRepGenVLM/projects/MG15_basic_overfitTesting_config.json
# [15:47:09] [DRGVLM_baseConfig.save] Saved config to /home/yasaisen/Desktop/27_research/research_main_v3/lab_18/DRepGenVLM/DRepGenVLM/projects/MG15_basic_PP4G_config_hpc.json
# [15:47:09] [DRGVLM_baseConfig.save] Saved config to /home/yasaisen/Desktop/27_research/research_main_v3/lab_18/DRepGenVLM/DRepGenVLM/projects/MG15_basic_PP4G_config.json
# [15:47:09] [DRGVLM_baseConfig.save] Saved config to /home/yasaisen/Desktop/27_research/research_main_v3/lab_18/DRepGenVLM/DRepGenVLM/projects/NULLMODE_config_hpc.json
# [15:47:09] [DRGVLM_baseConfig.save] Saved config to /home/yasaisen/Desktop/27_research/research_main_v3/lab_18/DRepGenVLM/DRepGenVLM/projects/NULLMODE_config.json
